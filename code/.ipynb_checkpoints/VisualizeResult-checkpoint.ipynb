# %%
from PIL import Image
import numpy as np
import glob
import os
import os.path as osp
import matplotlib.pyplot as plt
import cv2
import skimage

# %%
# acc_train1 = np.load('Train_Accuracies3.npy')[0:99]
# acc_val1 = np.load('Val_Accuracies3.npy')[0:99]
# acc_train2 = np.load('Train_Accuracies2.npy')
# acc_val2 = np.load('Val_Accuracies2.npy')
acc_train = np.load('Train_Accuracies2.npy')
acc_val = np.load('Val_Accuracies2.npy')

# print(np.max(acc_train))
# print(np.max(acc_val))
# print(np.max(acc_train1))
# print(np.max(acc_train2))

# plt.subplot(2,1,1)
# plt.title('Accuracy')
plt.plot(acc_train, label = 'Training accuracy')
plt.plot(acc_val, label = 'Validation accuracy')
# plt.legend(loc='lower center') 

# plt.subplot(2,1,2)
# loss = np.load('Losses.npy')
# print('Max loss', np.max(loss))
# plt.plot(loss)

# plt.plot(acc_train2 * 100, label = 'Training accuracy of SPP')
# plt.plot(acc_val2 * 100, label = 'Validation accuracy of SPP')
# plt.plot(acc_train1 * 100, label = 'Training accuracy of SPP-Unet')
# plt.plot(acc_val1 * 100, label = 'Validation accuracy of SPP-Unet')
plt.title('Accuracy', fontsize=20)
plt.xlabel('Epoch', fontsize=18)
plt.legend(loc='lower center', fontsize=18) 

plt.gcf().set_size_inches(12, 8)
plt.show()

# %%
x = Image.open('./predict_im/PredtrainRGB2.png')
x
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F9107DE9E80>

# %%
pred = Image.open('./predict_im/Predtrain2.png')
pred
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=384x384 at 0x7F45159729B0>

# %%
label = Image.open('./predict_im/Predtrain2_label.png')
label
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=384x384 at 0x7F45159E7D68>

# %% [markdown]
# # Resnet18 with Transfer, no weighting, batch size 50, learning rate 5e-4

# %%
acc = np.load('Val_Accuracies.npy')
print(np.max(acc))
plt.plot(acc)
# Out:
# 0.9673136393229167

# %%
x = Image.open('./predict_im/PredvalRGB1.png')
x
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384 at 0x7F45177D8208>

# %%
pred = Image.open('./predict_im/Predval1.png')
pred
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=384x384 at 0x7F45177D8DA0>

# %%
label = Image.open('./predict_im/Predval1_label.png')
label
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=384x384 at 0x7F45177D89E8>
