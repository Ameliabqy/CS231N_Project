# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
acc = np.load('accuracy.npy')
print(np.max(acc))
plt.plot(acc)
# Out:
# 90.19300130208333

# %%
acc = np.load('loss.npy')
print(np.max(acc))
plt.plot(acc)
# Out:
# 3.408989906311035
