# %%
from util import *

import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

# %%
# preds_image = Image.open('../data/cvpr-2018-autonomous-driving/cropped_train_label/171206_034513181_Camera_5_instanceIds.png')
preds_image = Image.open('Preds.png')
preds = np.asarray(preds_image)
plt.imshow(preds)
print(np.unique(preds))
# Out:
# [  0 255]

# %%
y_image = Image.open('Truth.png')
y = np.asarray(y_image)
plt.imshow(y)
print(np.unique(y))
# Out:
# [  0 255]
