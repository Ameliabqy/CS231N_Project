# %%
from util import *

import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image

# %matplotlib inline

# %%
# preds_image = Image.open('../data/cvpr-2018-autonomous-driving/cropped_train_label/171206_034513181_Camera_5_instanceIds.png')
preds_image = Image.open('Pred3.png')
preds = np.asarray(preds_image)
plt.imshow(preds)
print(np.unique(preds))
# Out:
# [  0  17  33  34  35  36  38  40  49  66  85  86  97  98  99 113 161 162
#  163 164 165 167]

# %%
y_image = Image.open('Pred3_label.png')
y = np.asarray(y_image)
plt.imshow(y)
print(np.unique(y))
# Out:
# [ 0 33 36]
